# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D,  BatchNormalization, Add, Activation, MaxPooling2D, concatenate, Flatten, Dense, AveragePooling2D
from keras.optimizers import Adam
from tensorflow import keras
from keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers import Dense, Flatten
from keras.models import Sequential

# %%
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Path to the main flower dataset folder
dataset_folder = 'Fruits\Grapes'

# %%
# List of class names0
class_names = ['Black_Measles','Black_rot','Healthy','Isariopsis_Leaf_Spot']

# %%
# Load and preprocess images
data = []
labels = []

# %%
for class_idx, class_name in enumerate(class_names):
    class_folder = os.path.join(dataset_folder, class_name)
    for img_file in os.listdir(class_folder):
        img_path = os.path.join(class_folder, img_file)
        img = Image.open(img_path)
        img = img.resize((32, 32))
        img_array = np.array(img)
        data.append(img_array)
        labels.append(class_idx)

# %%
# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
# Split the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# Split the data into training, validation, and testing sets
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# %%
# Print the shapes of the datasets
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_val shape", x_val.shape)
print("y_val shape :", y_val.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1934, 32, 32, 3)
# y_train shape: (1934,)
# x_val shape (484, 32, 32, 3)
# y_val shape : (484,)
# x_test shape: (605, 32, 32, 3)
# y_test shape: (605,)

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# %%
# Convert labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train, 4)
y_val = keras.utils.to_categorical(y_val, 4)
y_test = keras.utils.to_categorical(y_test, 4)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)
early_stopping=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)

# %%
from tensorflow.keras import layers, Sequential
from keras import applications 
from tensorflow.keras.optimizers import SGD
from keras.layers  import Input
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten, Dense, Dropout
from keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
#custom Model
customModel = Sequential()
customModel=Sequential(
    [
        layers.Conv2D(512,3,input_shape=(32,32,3),padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Flatten(),

        layers.Dense(512,activation='relu'),
        layers.Dense(256,activation='relu'),
        layers.Dense(128,activation='relu'),
        layers.Dense(4,activation='softmax'),
    ]
)

# %%
customModel.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
customModel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 512)       14336
#
#  batch_normalization (Batch  (None, 32, 32, 512)       2048
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 512)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)       1179904
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         295040
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_2 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          73792
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 64)          36928
#
#  batch_normalization_3 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 32)          18464
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 32)          9248
#
#  batch_normalization_4 (Bat  (None, 2, 2, 32)          128
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 512)               16896
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2550980 (9.73 MB)
# Trainable params: 2548996 (9.72 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
y_train.shape
# Out:
# (1934, 4)

# %%
history = customModel.fit(
    x_train,y_train,
    epochs=35,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint,early_stopping])
# Out:
# Epoch 1/35
# 61/61 [==============================] - ETA: 0s - loss: 0.7850 - accuracy: 0.6479
# c:\Users\VAIBHAV\PycharmProjects\pythonProject\venv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 75s 1s/step - loss: 0.7850 - accuracy: 0.6479 - val_loss: 1.7441 - val_accuracy: 0.2707
# Epoch 2/35
# 61/61 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.7968WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.4948 - accuracy: 0.7968 - val_loss: 2.4082 - val_accuracy: 0.2707
# Epoch 3/35
# 61/61 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.8030WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.4938 - accuracy: 0.8030 - val_loss: 1.5686 - val_accuracy: 0.3657
# Epoch 4/35
# 61/61 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8666WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.3499 - accuracy: 0.8666 - val_loss: 2.1377 - val_accuracy: 0.2769
# Epoch 5/35
# 61/61 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8687WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.3357 - accuracy: 0.8687 - val_loss: 5.7485 - val_accuracy: 0.2707
# Epoch 6/35
# 61/61 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.8997WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.2578 - accuracy: 0.8997 - val_loss: 5.4843 - val_accuracy: 0.2707
# Epoch 7/35
# 61/61 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8671WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.3614 - accuracy: 0.8671 - val_loss: 4.8014 - val_accuracy: 0.2707
# Epoch 8/35
# 61/61 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8893WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 66s 1s/step - loss: 0.2888 - accuracy: 0.8893 - val_loss: 2.2909 - val_accuracy: 0.4008
# Epoch 9/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9302WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.1728 - accuracy: 0.9302 - val_loss: 0.4177 - val_accuracy: 0.8926
# Epoch 10/35
# 61/61 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9261WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.2085 - accuracy: 0.9261 - val_loss: 0.2884 - val_accuracy: 0.8946
# Epoch 11/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9509WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.1306 - accuracy: 0.9509 - val_loss: 1.0997 - val_accuracy: 0.6612
# Epoch 12/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9447WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.1558 - accuracy: 0.9447 - val_loss: 1.2810 - val_accuracy: 0.6426
# Epoch 13/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9695WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 66s 1s/step - loss: 0.1011 - accuracy: 0.9695 - val_loss: 0.4403 - val_accuracy: 0.8430
# Epoch 14/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9597WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.1081 - accuracy: 0.9597 - val_loss: 0.4097 - val_accuracy: 0.8595
# Epoch 15/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9581WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.1386 - accuracy: 0.9581 - val_loss: 0.7898 - val_accuracy: 0.7459
# Epoch 16/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9736WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 61s 1s/step - loss: 0.0805 - accuracy: 0.9736 - val_loss: 0.8746 - val_accuracy: 0.7686
# Epoch 17/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9778WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 62s 1s/step - loss: 0.0719 - accuracy: 0.9778 - val_loss: 1.0973 - val_accuracy: 0.7397
# Epoch 18/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9602WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 62s 1s/step - loss: 0.1044 - accuracy: 0.9602 - val_loss: 1.2306 - val_accuracy: 0.6880
# Epoch 19/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9804WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 68s 1s/step - loss: 0.0590 - accuracy: 0.9804 - val_loss: 1.2489 - val_accuracy: 0.6777
# Epoch 20/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9747WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 64s 1s/step - loss: 0.0829 - accuracy: 0.9747 - val_loss: 1.1363 - val_accuracy: 0.7397
# Epoch 21/35
# 61/61 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9592WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 65s 1s/step - loss: 0.1086 - accuracy: 0.9592 - val_loss: 0.7171 - val_accuracy: 0.7831
# Epoch 22/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9772WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 66s 1s/step - loss: 0.0641 - accuracy: 0.9772 - val_loss: 0.2513 - val_accuracy: 0.9318
# Epoch 23/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9778WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 66s 1s/step - loss: 0.0663 - accuracy: 0.9778 - val_loss: 0.5709 - val_accuracy: 0.8492
# Epoch 24/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9829WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 71s 1s/step - loss: 0.0525 - accuracy: 0.9829 - val_loss: 0.9619 - val_accuracy: 0.7851
# Epoch 25/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9845WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 78s 1s/step - loss: 0.0400 - accuracy: 0.9845 - val_loss: 0.1988 - val_accuracy: 0.9380
# Epoch 26/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9840WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 79s 1s/step - loss: 0.0509 - accuracy: 0.9840 - val_loss: 0.1493 - val_accuracy: 0.9587
# Epoch 27/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9964WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 80s 1s/step - loss: 0.0197 - accuracy: 0.9964 - val_loss: 0.1536 - val_accuracy: 0.9607
# Epoch 28/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9835WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 78s 1s/step - loss: 0.0430 - accuracy: 0.9835 - val_loss: 0.1530 - val_accuracy: 0.9504
# Epoch 29/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9819WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 78s 1s/step - loss: 0.0548 - accuracy: 0.9819 - val_loss: 0.5410 - val_accuracy: 0.8946
# Epoch 30/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9855WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 74s 1s/step - loss: 0.0401 - accuracy: 0.9855 - val_loss: 0.1857 - val_accuracy: 0.9421
# Epoch 31/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 78s 1s/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.3830 - val_accuracy: 0.9215
# Epoch 32/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 80s 1s/step - loss: 0.0348 - accuracy: 0.9907 - val_loss: 0.1569 - val_accuracy: 0.9566
# Epoch 33/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 73s 1s/step - loss: 0.0208 - accuracy: 0.9933 - val_loss: 1.3601 - val_accuracy: 0.7603
# Epoch 34/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 73s 1s/step - loss: 0.0363 - accuracy: 0.9886 - val_loss: 0.3670 - val_accuracy: 0.9070
# Epoch 35/35
# 61/61 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 61/61 [==============================] - 71s 1s/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 1.9383 - val_accuracy: 0.7459

# %%
val_loss, val_acc = customModel.evaluate(x_val,y_val)
print('Validation accuracy : ', val_acc)
# Out:
# 16/16 [==============================] - 4s 277ms/step - loss: 1.9383 - accuracy: 0.7459
# Validation accuracy :  0.7458677887916565

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix,classification_report
valid_pres=customModel.predict(x_val)
valid_pred = [np.argmax(pred) for pred in valid_pres]
y_val = np.argmax(y_val, axis=1)
cm =confusion_matrix(y_val,valid_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in class_names] , columns = [i for i in class_names])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='.2f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_val,valid_pred))
# Out:
# 16/16 [==============================] - 4s 247ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81       144
#            1       0.53      1.00      0.70       141
#            2       1.00      0.18      0.30        68
#            3       1.00      0.84      0.91       131
#
#     accuracy                           0.75       484
#    macro avg       0.88      0.67      0.68       484
# weighted avg       0.86      0.75      0.73       484

# %%
score = customModel.evaluate(x_test, y_test)
# Out:
# 19/19 [==============================] - 5s 245ms/step - loss: 2.0981 - accuracy: 0.7190

# %%
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test Loss: 2.0980632305145264
# Test accuracy: 0.7190082669258118

# %%
customModel.save('Grapes_Saved_Model')
# Out:
# INFO:tensorflow:Assets written to: Grapes_Saved_Model\assets
# INFO:tensorflow:Assets written to: Grapes_Saved_Model\assets

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import tensorflow as tf
model = tf.keras.models.load_model('Grapes_Saved_Model')

# %%
def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((32, 32))
    
    # Convert to RGB in case the image has an alpha channel
    img = img.convert('RGB')
    
    img_array = np.array(img)
    img_array = img_array.astype('float32') / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# %%
# List of class names0
class_names = ['Black_Measles','Black_rot','Healthy','Isariopsis_Leaf_Spot']

# %%
# Predict the class
image_path = 'flowers/rose/12240303_80d87f77a3_n.jpg'
input_image = preprocess_image(image_path)
predictions = model.predict(input_image)

predicted_class = np.argmax(predictions)
predicted_class_name = class_names[predicted_class]

print("Predicted class:", predicted_class_name)

# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D,  BatchNormalization, Add, Activation, MaxPooling2D, concatenate, Flatten, Dense, AveragePooling2D
from keras.optimizers import Adam
from tensorflow import keras
from keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers import Dense, Flatten
from keras.models import Sequential

# %%
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Path to the main flower dataset folder
dataset_folder = 'Crops\Wheat'


# List of class names
class_names = ['Brown_Rust','Healthy','Yellow_Rust']

# %%
# Load and preprocess images
data = []
labels = []

for class_idx, class_name in enumerate(class_names):
    class_folder = os.path.join(dataset_folder, class_name)
    for img_file in os.listdir(class_folder):
        img_path = os.path.join(class_folder, img_file)
        img = Image.open(img_path)
        img = img.resize((32, 32))
        img_array = np.array(img)
        data.append(img_array)
        labels.append(class_idx)

# %%
# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training, validation, and testing sets
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# %%
# Print the shapes of the datasets
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_val shape", x_val.shape)
print("y_val shape :", y_val.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1882, 32, 32, 3)
# y_train shape: (1882,)
# x_val shape (471, 32, 32, 3)
# y_val shape : (471,)
# x_test shape: (589, 32, 32, 3)
# y_test shape: (589,)

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# %%
# Convert labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train, 3)
y_val = keras.utils.to_categorical(y_val, 3)
y_test = keras.utils.to_categorical(y_test, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)
early_stopping=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)

# %%
from tensorflow.keras import layers, Sequential
from keras import applications 
from tensorflow.keras.optimizers import SGD
from keras.layers  import Input
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten, Dense, Dropout
from keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
#custom Model
customModel = Sequential()
customModel=Sequential(
    [
        layers.Conv2D(512,3,input_shape=(32,32,3),padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Flatten(),

        layers.Dense(512,activation='relu'),
        layers.Dense(256,activation='relu'),
        layers.Dense(128,activation='relu'),
        layers.Dense(3,activation='softmax'),
    ]
)

# %%
customModel.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
customModel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)       14336
#
#  batch_normalization_5 (Bat  (None, 32, 32, 512)       2048
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         295040
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_7 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 64)          73792
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 64)          36928
#
#  batch_normalization_8 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 32)          18464
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 32)          9248
#
#  batch_normalization_9 (Bat  (None, 2, 2, 32)          128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 512)               16896
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2550851 (9.73 MB)
# Trainable params: 2548867 (9.72 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
y_train.shape
# Out:
# (1882, 3)

# %%
history = customModel.fit(
    x_train,y_train,
    epochs=35,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint,early_stopping])
# Out:
# Epoch 1/35
# 59/59 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.7545
# c:\Users\VAIBHAV\PycharmProjects\pythonProject\venv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 70s 1s/step - loss: 0.5692 - accuracy: 0.7545 - val_loss: 7.0281 - val_accuracy: 0.3057
# Epoch 2/35
# 59/59 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.8804WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 63s 1s/step - loss: 0.3238 - accuracy: 0.8804 - val_loss: 3.1439 - val_accuracy: 0.3057
# Epoch 3/35
# 59/59 [==============================] - ETA: 0s - loss: 0.2502 - accuracy: 0.9129WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 60s 1s/step - loss: 0.2502 - accuracy: 0.9129 - val_loss: 6.4453 - val_accuracy: 0.3057
# Epoch 4/35
# 59/59 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9049WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 59s 997ms/step - loss: 0.2687 - accuracy: 0.9049 - val_loss: 5.2524 - val_accuracy: 0.3057
# Epoch 5/35
# 59/59 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.9081WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 57s 972ms/step - loss: 0.2542 - accuracy: 0.9081 - val_loss: 6.4290 - val_accuracy: 0.3057
# Epoch 6/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9378WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 53s 907ms/step - loss: 0.1881 - accuracy: 0.9378 - val_loss: 4.7670 - val_accuracy: 0.3057
# Epoch 7/35
# 59/59 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9208WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 67s 1s/step - loss: 0.2120 - accuracy: 0.9208 - val_loss: 5.3850 - val_accuracy: 0.3057
# Epoch 8/35
# 59/59 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9203WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 57s 968ms/step - loss: 0.2289 - accuracy: 0.9203 - val_loss: 2.0884 - val_accuracy: 0.3248
# Epoch 9/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9516WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 57s 976ms/step - loss: 0.1564 - accuracy: 0.9516 - val_loss: 1.8787 - val_accuracy: 0.4374
# Epoch 10/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9453WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 58s 984ms/step - loss: 0.1619 - accuracy: 0.9453 - val_loss: 1.9182 - val_accuracy: 0.6263
# Epoch 11/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9506WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 56s 947ms/step - loss: 0.1431 - accuracy: 0.9506 - val_loss: 1.7972 - val_accuracy: 0.4586
# Epoch 12/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9410WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 58s 988ms/step - loss: 0.1611 - accuracy: 0.9410 - val_loss: 2.8149 - val_accuracy: 0.4204
# Epoch 13/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9400WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 67s 1s/step - loss: 0.1711 - accuracy: 0.9400 - val_loss: 1.8178 - val_accuracy: 0.5796
# Epoch 14/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9501WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 73s 1s/step - loss: 0.1502 - accuracy: 0.9501 - val_loss: 0.2417 - val_accuracy: 0.9045
# Epoch 15/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9543WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 68s 1s/step - loss: 0.1201 - accuracy: 0.9543 - val_loss: 2.2519 - val_accuracy: 0.5393
# Epoch 16/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9490WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 118s 2s/step - loss: 0.1416 - accuracy: 0.9490 - val_loss: 0.5359 - val_accuracy: 0.8493
# Epoch 17/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9644WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 119s 2s/step - loss: 0.1027 - accuracy: 0.9644 - val_loss: 0.6375 - val_accuracy: 0.8280
# Epoch 18/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9708WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 111s 2s/step - loss: 0.0913 - accuracy: 0.9708 - val_loss: 1.2816 - val_accuracy: 0.7473
# Epoch 19/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9511WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 113s 2s/step - loss: 0.1327 - accuracy: 0.9511 - val_loss: 1.1584 - val_accuracy: 0.7707
# Epoch 20/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9601WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 111s 2s/step - loss: 0.1155 - accuracy: 0.9601 - val_loss: 1.7061 - val_accuracy: 0.6348
# Epoch 21/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9644WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 113s 2s/step - loss: 0.1033 - accuracy: 0.9644 - val_loss: 0.5014 - val_accuracy: 0.8217
# Epoch 22/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9756WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 114s 2s/step - loss: 0.0700 - accuracy: 0.9756 - val_loss: 0.2100 - val_accuracy: 0.9214
# Epoch 23/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9814WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 110s 2s/step - loss: 0.0631 - accuracy: 0.9814 - val_loss: 0.8309 - val_accuracy: 0.7962
# Epoch 24/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9772WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 125s 2s/step - loss: 0.0644 - accuracy: 0.9772 - val_loss: 0.3131 - val_accuracy: 0.9002
# Epoch 25/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9904WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 123s 2s/step - loss: 0.0316 - accuracy: 0.9904 - val_loss: 1.3534 - val_accuracy: 0.7919
# Epoch 26/35
# 59/59 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9586WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 128s 2s/step - loss: 0.1311 - accuracy: 0.9586 - val_loss: 0.5580 - val_accuracy: 0.8832
# Epoch 27/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9825WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 129s 2s/step - loss: 0.0643 - accuracy: 0.9825 - val_loss: 2.8042 - val_accuracy: 0.6858
# Epoch 28/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9761WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 127s 2s/step - loss: 0.0826 - accuracy: 0.9761 - val_loss: 0.4730 - val_accuracy: 0.8684
# Epoch 29/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9872WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 127s 2s/step - loss: 0.0421 - accuracy: 0.9872 - val_loss: 0.5967 - val_accuracy: 0.8174
# Epoch 30/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9777WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 124s 2s/step - loss: 0.0655 - accuracy: 0.9777 - val_loss: 0.3793 - val_accuracy: 0.9066
# Epoch 31/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9883WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 126s 2s/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.8387 - val_accuracy: 0.8599
# Epoch 32/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9702WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 123s 2s/step - loss: 0.0968 - accuracy: 0.9702 - val_loss: 3.5134 - val_accuracy: 0.5456
# Epoch 33/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9772WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 122s 2s/step - loss: 0.0704 - accuracy: 0.9772 - val_loss: 0.5736 - val_accuracy: 0.8365
# Epoch 34/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 125s 2s/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.2754 - val_accuracy: 0.9214
# Epoch 35/35
# 59/59 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9867WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 59/59 [==============================] - 118s 2s/step - loss: 0.0328 - accuracy: 0.9867 - val_loss: 0.7209 - val_accuracy: 0.8535

# %%
val_loss, val_acc = customModel.evaluate(x_val,y_val)
print('Validation accuracy : ', val_acc)
# Out:
# 15/15 [==============================] - 7s 483ms/step - loss: 0.7209 - accuracy: 0.8535
# Validation accuracy :  0.8535031676292419

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix,classification_report
valid_pres=customModel.predict(x_val)
valid_pred = [np.argmax(pred) for pred in valid_pres]
y_val = np.argmax(y_val, axis=1)
cm =confusion_matrix(y_val,valid_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in class_names] , columns = [i for i in class_names])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='.2f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_val,valid_pred))
# Out:
# 15/15 [==============================] - 4s 234ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.72      0.83       144
#            1       0.83      0.99      0.91       179
#            2       0.79      0.82      0.81       148
#
#     accuracy                           0.85       471
#    macro avg       0.87      0.84      0.85       471
# weighted avg       0.87      0.85      0.85       471

# %%
score = customModel.evaluate(x_test, y_test)
    
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 19/19 [==============================] - 5s 265ms/step - loss: 0.8703 - accuracy: 0.8489
# Test Loss: 0.8703308701515198
# Test accuracy: 0.8488964438438416

# %%
customModel.save('Wheat_Saved_Model')
# Out:
# INFO:tensorflow:Assets written to: Wheat_Saved_Model\assets
# INFO:tensorflow:Assets written to: Wheat_Saved_Model\assets

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import tensorflow as tf
model = tf.keras.models.load_model('Wheat_Saved_Model')

# %%
def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((32, 32))
    
    # Convert to RGB in case the image has an alpha channel
    img = img.convert('RGB')
    
    img_array = np.array(img)
    img_array = img_array.astype('float32') / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# %%
# List of class names
class_names = ['Brown_Rust','Healthy','Yellow_Rust']

# %%
# Predict the class
image_path = 'flowers/rose/12240303_80d87f77a3_n.jpg'
input_image = preprocess_image(image_path)
predictions = model.predict(input_image)

predicted_class = np.argmax(predictions)
predicted_class_name = class_names[predicted_class]

print("Predicted class:", predicted_class_name)

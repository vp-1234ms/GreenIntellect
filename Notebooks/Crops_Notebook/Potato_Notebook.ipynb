# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D,  BatchNormalization, Add, Activation, MaxPooling2D, concatenate, Flatten, Dense, AveragePooling2D
from keras.optimizers import Adam
from tensorflow import keras
from keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers import Dense, Flatten
from keras.models import Sequential

# %%
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Path to the main flower dataset folder
dataset_folder = 'Crops\Potato'

# %%
# List of class names
class_names = ['Early_blight','Healthy','Late_blight']

# %%
# Load and preprocess images
data = []
labels = []

# %%
for class_idx, class_name in enumerate(class_names):
    class_folder = os.path.join(dataset_folder, class_name)
    for img_file in os.listdir(class_folder):
        img_path = os.path.join(class_folder, img_file)
        img = Image.open(img_path)
        img = img.resize((32, 32))
        img_array = np.array(img)
        data.append(img_array)
        labels.append(class_idx)

# %%
# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)
# Split the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# Split the data into training, validation, and testing sets
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# %%
# Print the shapes of the datasets
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_val shape", x_val.shape)
print("y_val shape :", y_val.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (912, 32, 32, 3)
# y_train shape: (912,)
# x_val shape (228, 32, 32, 3)
# y_val shape : (228,)
# x_test shape: (286, 32, 32, 3)
# y_test shape: (286,)

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# %%
# Convert labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train, 3)
y_val = keras.utils.to_categorical(y_val, 3)
y_test = keras.utils.to_categorical(y_test, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)
early_stopping=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)

# %%
from tensorflow.keras import layers, Sequential
from keras import applications 
from tensorflow.keras.optimizers import SGD
from keras.layers  import Input
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten, Dense, Dropout
from keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
#custom Model
customModel = Sequential()
customModel=Sequential(
    [
        layers.Conv2D(512,3,input_shape=(32,32,3),padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.Conv2D(256,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.Conv2D(128,3,padding='same',activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.BatchNormalization(),        
        layers.MaxPooling2D(),
        layers.Flatten(),

        layers.Dense(512,activation='relu'),
        layers.Dense(256,activation='relu'),
        layers.Dense(128,activation='relu'),
        layers.Dense(3,activation='softmax'),
    ]
)

# %%
customModel.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
customModel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)       14336
#
#  batch_normalization_5 (Bat  (None, 32, 32, 512)       2048
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         295040
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_7 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 64)          73792
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 64)          36928
#
#  batch_normalization_8 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 32)          18464
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 32)          9248
#
#  batch_normalization_9 (Bat  (None, 2, 2, 32)          128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 512)               16896
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2550851 (9.73 MB)
# Trainable params: 2548867 (9.72 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
y_train.shape
# Out:
# (912, 3)

# %%
history = customModel.fit(
    x_train,y_train,
    epochs=35,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint,early_stopping])
# Out:
# Epoch 1/35
# 29/29 [==============================] - ETA: 0s - loss: 0.5800 - accuracy: 0.7708
# c:\Users\VAIBHAV\PycharmProjects\pythonProject\venv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 37s 1s/step - loss: 0.5800 - accuracy: 0.7708 - val_loss: 0.9590 - val_accuracy: 0.4737
# Epoch 2/35
# 29/29 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8673WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 36s 1s/step - loss: 0.3464 - accuracy: 0.8673 - val_loss: 0.9478 - val_accuracy: 0.4912
# Epoch 3/35
# 29/29 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9013WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.2725 - accuracy: 0.9013 - val_loss: 2.6717 - val_accuracy: 0.4474
# Epoch 4/35
# 29/29 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.8871WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 35s 1s/step - loss: 0.3019 - accuracy: 0.8871 - val_loss: 1.8387 - val_accuracy: 0.4474
# Epoch 5/35
# 29/29 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.9057WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 31s 1s/step - loss: 0.2610 - accuracy: 0.9057 - val_loss: 2.6808 - val_accuracy: 0.4474
# Epoch 6/35
# 29/29 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9002WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.2676 - accuracy: 0.9002 - val_loss: 2.0200 - val_accuracy: 0.4474
# Epoch 7/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9419WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 35s 1s/step - loss: 0.1708 - accuracy: 0.9419 - val_loss: 2.5135 - val_accuracy: 0.4474
# Epoch 8/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9485WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.1510 - accuracy: 0.9485 - val_loss: 3.8101 - val_accuracy: 0.4474
# Epoch 9/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9594WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.1137 - accuracy: 0.9594 - val_loss: 1.4301 - val_accuracy: 0.7719
# Epoch 10/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9518WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.1229 - accuracy: 0.9518 - val_loss: 2.4044 - val_accuracy: 0.5219
# Epoch 11/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9649WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0944 - accuracy: 0.9649 - val_loss: 5.3810 - val_accuracy: 0.4825
# Epoch 12/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9693WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0875 - accuracy: 0.9693 - val_loss: 2.8609 - val_accuracy: 0.5789
# Epoch 13/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1509 - accuracy: 0.9539WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.1509 - accuracy: 0.9539 - val_loss: 1.9039 - val_accuracy: 0.6930
# Epoch 14/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9814WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0677 - accuracy: 0.9814 - val_loss: 1.5195 - val_accuracy: 0.7149
# Epoch 15/35
# 29/29 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9605WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.1268 - accuracy: 0.9605 - val_loss: 0.8220 - val_accuracy: 0.8596
# Epoch 16/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9682WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0962 - accuracy: 0.9682 - val_loss: 2.0407 - val_accuracy: 0.5614
# Epoch 17/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9803WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0594 - accuracy: 0.9803 - val_loss: 3.5157 - val_accuracy: 0.6842
# Epoch 18/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9759WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 35s 1s/step - loss: 0.0877 - accuracy: 0.9759 - val_loss: 5.4031 - val_accuracy: 0.4474
# Epoch 19/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9792WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0774 - accuracy: 0.9792 - val_loss: 5.0217 - val_accuracy: 0.4474
# Epoch 20/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9825WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 35s 1s/step - loss: 0.0507 - accuracy: 0.9825 - val_loss: 5.3850 - val_accuracy: 0.4649
# Epoch 21/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9901WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0308 - accuracy: 0.9901 - val_loss: 4.2290 - val_accuracy: 0.5307
# Epoch 22/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9912WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0387 - accuracy: 0.9912 - val_loss: 1.6747 - val_accuracy: 0.7325
# Epoch 23/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9759WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0773 - accuracy: 0.9759 - val_loss: 8.4015 - val_accuracy: 0.4518
# Epoch 24/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9693WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0735 - accuracy: 0.9693 - val_loss: 1.1097 - val_accuracy: 0.8202
# Epoch 25/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9781WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0606 - accuracy: 0.9781 - val_loss: 0.8694 - val_accuracy: 0.7281
# Epoch 26/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9770WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0667 - accuracy: 0.9770 - val_loss: 0.3613 - val_accuracy: 0.8640
# Epoch 27/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9770WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0676 - accuracy: 0.9770 - val_loss: 1.3192 - val_accuracy: 0.6667
# Epoch 28/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9857WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0335 - accuracy: 0.9857 - val_loss: 0.5096 - val_accuracy: 0.8640
# Epoch 29/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9825WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0366 - accuracy: 0.9825 - val_loss: 1.2183 - val_accuracy: 0.7763
# Epoch 30/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9814WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0408 - accuracy: 0.9814 - val_loss: 0.3926 - val_accuracy: 0.8947
# Epoch 31/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9825WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 34s 1s/step - loss: 0.0373 - accuracy: 0.9825 - val_loss: 1.5017 - val_accuracy: 0.6754
# Epoch 32/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9956WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 35s 1s/step - loss: 0.0222 - accuracy: 0.9956 - val_loss: 3.4232 - val_accuracy: 0.5614
# Epoch 33/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9857WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 38s 1s/step - loss: 0.0484 - accuracy: 0.9857 - val_loss: 5.2693 - val_accuracy: 0.4825
# Epoch 34/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 33s 1s/step - loss: 0.0286 - accuracy: 0.9890 - val_loss: 0.7945 - val_accuracy: 0.7632
# Epoch 35/35
# 29/29 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9836WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 29/29 [==============================] - 37s 1s/step - loss: 0.0550 - accuracy: 0.9836 - val_loss: 0.7871 - val_accuracy: 0.7851

# %%
val_loss, val_acc = customModel.evaluate(x_val,y_val)
print('Validation accuracy : ', val_acc)


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# 8/8 [==============================] - 2s 261ms/step - loss: 0.7871 - accuracy: 0.7851
# Validation accuracy :  0.7850877046585083

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix,classification_report
valid_pres=customModel.predict(x_val)
valid_pred = [np.argmax(pred) for pred in valid_pres]
y_val = np.argmax(y_val, axis=1)
cm =confusion_matrix(y_val,valid_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in class_names] , columns = [i for i in class_names])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='.2f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_val,valid_pred))
# Out:
# 8/8 [==============================] - 3s 265ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74       102
#            1       0.72      0.96      0.82        24
#            2       0.71      0.94      0.81       102
#
#     accuracy                           0.79       228
#    macro avg       0.81      0.83      0.79       228
# weighted avg       0.84      0.79      0.78       228

# %%
score = customModel.evaluate(x_test, y_test)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 9/9 [==============================] - 3s 291ms/step - loss: 0.5724 - accuracy: 0.8147
# Test Loss: 0.5724087953567505
# Test accuracy: 0.8146852850914001

# %%
customModel.save('Potato_Saved_Model')
# Out:
# INFO:tensorflow:Assets written to: Potato_Saved_Model\assets
# INFO:tensorflow:Assets written to: Potato_Saved_Model\assets

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import tensorflow as tf
model = tf.keras.models.load_model('Potato_Saved_Model')

# %%
def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((32, 32))
    
    # Convert to RGB in case the image has an alpha channel
    img = img.convert('RGB')
    
    img_array = np.array(img)
    img_array = img_array.astype('float32') / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# %%
# List of class names
class_names = ['Early_blight','Healthy','Late_blight']

# %%
# Predict the class
image_path = 'flowers/rose/12240303_80d87f77a3_n.jpg'
input_image = preprocess_image(image_path)
predictions = model.predict(input_image)

predicted_class = np.argmax(predictions)
predicted_class_name = class_names[predicted_class]

print("Predicted class:", predicted_class_name)
